# %%
import pandas as pd

data_nouns_dir = "../data/Nouns.csv"
data_verbs_dir = "../data/Verbs.csv"

df_nouns = pd.read_csv(data_nouns_dir, usecols=range(16))
df_verbs = pd.read_csv(data_verbs_dir, usecols=range(16))

# %%
df_verbs[df_verbs["Head"] != "NONE"].head(40)
# Out:
#      Paradigm Order   Class        Lemma         Stem         Head  \
# 1981      VAI   Pcp  VAI_VV     madaabii     madaabii   3PlObvHead
# 1982      VAI   Pcp   VAI_m   minongwaam   minongwaam   3PlObvHead
# 1983      VAI   Pcp   VAI_V       nagamo       nagamo   3PlObvHead
# 1984      VAI   Pcp  VAI_VV        nibaa        nibaa   3PlObvHead
# 1985      VAI   Pcp   VAI_V        niimi        niimi   3PlObvHead
# 1986      VAI   Pcp   VAI_n     wanishin     wanishin   3PlObvHead
# 1987      VAI   Pcp  VAI_VV     webinige     webinige   3PlObvHead
# 1988      VAI   Pcp  VAI_am     zaaga'am       zaaga'   3PlObvHead
# 1989      VAI   Pcp  VAI_VV  maajiibatoo  maajiibatoo   3PlObvHead
# 1990      VAI   Pcp  VAI_VV     madaabii     madaabii   3PlObvHead
# 1991      VAI   Pcp   VAI_m   minongwaam   minongwaam   3PlObvHead
# 1992      VAI   Pcp   VAI_V       nagamo       nagamo   3PlObvHead
# 1993      VAI   Pcp  VAI_VV        nibaa        nibaa   3PlObvHead
# ...
