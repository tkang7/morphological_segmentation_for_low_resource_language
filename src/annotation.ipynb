# %%
import pandas as pd

# %%
import pandas as pd

data_nouns_dir = "../data/Nouns.csv"
data_verbs_dir = "../data/Verbs.csv"

df_nouns = pd.read_csv(data_nouns_dir, usecols=range(16))
df_verbs = pd.read_csv(data_verbs_dir, usecols=range(16))

# %%
df_nouns.head(11)
# Out:
#    Paradigm  Class Lemma  Stem     PersPoss   Dim  Poss   Pej  Pret Basic  \
# 0       NAD  NAD_C  naan  naan      1SgPoss  NONE  NONE  NONE  NONE   Loc
# 1       NAD  NAD_C  naan  naan     ExclPoss  NONE  NONE  NONE  NONE   Loc
# 2       NAD  NAD_C  naan  naan     InclPoss  NONE  NONE  NONE  NONE   Loc
# 3       NAD  NAD_C  naan  naan      2SgPoss  NONE  NONE  NONE  NONE   Loc
# 4       NAD  NAD_C  naan  naan      2PlPoss  NONE  NONE  NONE  NONE   Loc
# 5       NAD  NAD_C  naan  naan  3SgProxPoss  NONE  NONE  NONE  NONE   Loc
# 6       NAD  NAD_C  naan  naan  3PlProxPoss  NONE  NONE  NONE  NONE   Loc
# 7       NAD  NAD_C  naan  naan   3SgObvPoss  NONE  NONE  NONE  NONE   Loc
# 8       NAD  NAD_C  naan  naan   3PlObvPoss  NONE  NONE  NONE  NONE   Loc
# 9       NAD  NAD_C  naan  naan      1SgPoss   Dim  NONE  NONE  NONE   Loc
# 10      NAD  NAD_C  naan  naan     ExclPoss   Dim  NONE  NONE  NONE   Loc
#
#        Form1Surface          Form1Split     Form1Source Form2Surface  \
# ...

# %% [markdown]
# # Ten annotation for lemma 'naan' (index 0-10):

# %%
naan_lst = [
    ("ninaaning", ["ni", "naan", "ing"]),
    ("ninaaninaang", ["ni", "naan", "inaan", "g"]),
    ("ginaaninaang", ["gi", "naan", "inaan", "g"]),
    ("ginaaning", ["gi", "naan", "ing"]),
    ("ginaaniwaang", ["gi", "naan", "iwaa", "ng"]),
    ("onaaning", ["o", "naan", "ing"]),
    ("onaaniwaang", ["o", "naan", "iwaa", "ng"]),
    ("onaanining", ["o", "naan", "ining"]),
    ("onaanining", ["o", "naan", "ining"]),
    ("ninaanensing", ["ni", "naan", "ens", "ing"]),
    ("ninaanensinaang", ["ni", "naan", "ens", "inaan", "g"]),
]

# %% [markdown]
# # Ten annotations for lemma 'niigi\'igw':

# %%
niigiigw_df = df_nouns[df_nouns['Lemma'] == 'niigi\'igw']
niigiigw_df.sample(10)
# Out:
#     Paradigm   Class      Lemma        Stem    PersPoss   Dim  Poss   Pej  \
# 448      NAD  NAD_Cw  niigi'igw  niigi'igw2  3SgObvPoss   Dim  NONE   Pej
# 496      NAD  NAD_Cw  niigi'igw  niigi'igw2     2PlPoss   Dim  Poss   Pej
# 754      NAD  NAD_Cw  niigi'igw  niigi'igw2    InclPoss  NONE  Poss   Pej
# 691      NAD  NAD_Cw  niigi'igw  niigi'igw2    InclPoss  NONE  NONE   Pej
# 684      NAD  NAD_Cw  niigi'igw  niigi'igw2    InclPoss   Dim  NONE  NONE
# 736      NAD  NAD_Cw  niigi'igw  niigi'igw2    ExclPoss   Dim  Poss   Pej
# 522      NAD  NAD_Cw  niigi'igw  niigi'igw2  3PlObvPoss  NONE  NONE  NONE
# 744      NAD  NAD_Cw  niigi'igw  niigi'igw2    InclPoss   Dim  NONE  NONE
# 629      NAD  NAD_Cw  niigi'igw  niigi'igw2  3PlObvPoss  NONE  NONE  NONE
# 616      NAD  NAD_Cw  niigi'igw  niigi'igw2     2SgPoss   Dim  Poss   Pej
#
#      Pret   Basic                Form1Surface  \
# 448  NONE     Loc      oniigi'igoonzhishining
# 496  NONE   ObvPl    giniigi'igoonsimishiwaa'
# ...

# %%
niigiigw_lst = [
    ("oniigi'igoonsimining", ["o", "niigi'igw2", "oons", "im", "in", "ing"]),
    ("niniigi'igoonsimishag", ["ni", "niigi'igw2", "oons", "im", "ish", "ag"]),
    ("niniigi'igom", ["ni", "niigi'igw2", "om"]),
    ("giniigi'igoonzhishiwaa'", ["gi", "niigi'igw2", "oonzh", "ish", "iwaa"]),
    ("giniigi'igoonzhishing", ["gi", "niigi'igw2", "oonzh", "ish", "ing"]),
    ("oniigi'igoonsini", ["o", "niigi'igw2", "oons", "ini"]),
    ("giniigi'igomibaniin", ["gi", "niigi'igw2", "om", "ibaniin"]),
    ("oniigi'igoonsimiwaa'", ["o", "niigi'igw2", "oons", "im", "iwaa"]),
    ("giniigi'igoonsimiwaag", ["gi", "niigi'igw2", "oons", "im", "iwaa", "g"]),
    ("niniigi'igominaanig", ["ni", "niigi'igw2", "om", "inaan", "ig"])
]

# %% [markdown]
# # Ten annotations for lemma 'shkanzhy':

# %%
shkanzhy_df = df_nouns[df_nouns['Lemma'] == 'shkanzhy']
shkanzhy_df.sample(10)
# Out:
#      Paradigm   Class     Lemma       Stem     PersPoss   Dim  Poss   Pej  \
# 846       NAD  NAD_Cy  shkanzhy  shkanzhy2  3SgProxPoss   Dim  Poss  NONE
# 1212      NAD  NAD_Cy  shkanzhy  shkanzhy2      1SgPoss   Dim  NONE   Pej
# 1154      NAD  NAD_Cy  shkanzhy  shkanzhy2     InclPoss   Dim  NONE   Pej
# 1156      NAD  NAD_Cy  shkanzhy  shkanzhy2      2PlPoss   Dim  NONE   Pej
# 967       NAD  NAD_Cy  shkanzhy  shkanzhy2      1SgPoss   Dim  Poss  NONE
# 876       NAD  NAD_Cy  shkanzhy  shkanzhy2   3PlObvPoss   Dim  NONE   Pej
# 1210      NAD  NAD_Cy  shkanzhy  shkanzhy2      2SgPoss   Dim  Poss  NONE
# 1005      NAD  NAD_Cy  shkanzhy  shkanzhy2     InclPoss  NONE  Poss  NONE
# 884       NAD  NAD_Cy  shkanzhy  shkanzhy2   3SgObvPoss   Dim  Poss   Pej
# 950       NAD  NAD_Cy  shkanzhy  shkanzhy2     ExclPoss  NONE  Poss  NONE
#
#       Pret   Basic              Form1Surface                     Form1Split  \
# 846   NONE     Loc         oshkanzhiinsiming        w<<shkanzhy2>>iinsiming
# ...

# %%
shkanzhy_lst = [
    ("gishkanzhiiminaabanii'", ["gi", "shkanzhy2", "iim", "inaan", "aban", "ii"]),
    ("oshkanzhiiminiban", ["o", "shkanzhy2", "iim", "in", "ban"]),
    ("gishkanzhiinsiminaani'", ["gi", "shkanzhy2", "iins", "im", "inaan", "i"]),
    ("oshkanzhiini", ["o", "shkanzhy2", "iini"]),
    ("gishkanzhiinzhishag", ["gi", "shkanzhy2", "iins", "ish", "ag"]),
    ("oshkanzhiinsiwaang", ["o", "shkanzhy2", "iins", "iwaa", "ng"]),
    ("gishkanzhiimiwaa'", ["gi", "shkanzhy2", "iim", "iwaa"]),
    ("gishkanzhiinsiminaanin", ["gi", "shkanzhy2", "iins", "im", "inaan", "in"]),
    ("gishkanzhiimag", ["gi", "shkanzhy2", "iim", "ag"]),
    ("gishkanzhiimiwaag", ["gi", "shkanzhy2", "iim", "iwaa", "g"])
]

# %%
lst = naan_lst + niigiigw_lst + shkanzhy_lst

# %% [markdown]
# # Ten annotations for lemma 'dawemaaw':

# %%
dawemaaw_df = df_nouns[df_nouns['Lemma'] == 'dawemaaw']
dawemaaw_df.sample(10)
# Out:
#      Paradigm   Class     Lemma       Stem     PersPoss   Dim  Poss   Pej  \
# 1411      NAD  NAD_VV  dawemaaw  dawemaaw2     ExclPoss  NONE  Poss  NONE
# 1511      NAD  NAD_VV  dawemaaw  dawemaaw2     InclPoss  NONE  NONE  NONE
# 1313      NAD  NAD_VV  dawemaaw  dawemaaw2     InclPoss   Dim  NONE  NONE
# 1496      NAD  NAD_VV  dawemaaw  dawemaaw2  3SgProxPoss   Dim  NONE   Pej
# 1263      NAD  NAD_VV  dawemaaw  dawemaaw2  3PlProxPoss  NONE  NONE   Pej
# 1441      NAD  NAD_VV  dawemaaw  dawemaaw2      2PlPoss  NONE  NONE   Pej
# 1581      NAD  NAD_VV  dawemaaw  dawemaaw2     InclPoss   Dim  NONE  NONE
# 1351      NAD  NAD_VV  dawemaaw  dawemaaw2      2PlPoss  NONE  NONE  NONE
# 1249      NAD  NAD_VV  dawemaaw  dawemaaw2     ExclPoss   Dim  Poss  NONE
# 1419      NAD  NAD_VV  dawemaaw  dawemaaw2      1SgPoss   Dim  NONE  NONE
#
#       Pret   Basic         Form1Surface                Form1Split  \
# 1411  NONE   ObvSg    nidawemaaminaanin    n<<dawemaaw2>>minaanin
# ...

# %%
dawemaaw_lst = [
    ("gidawemaawisha'", ["gi", "dawemaaw2", "ish", "a"]),
    ("gidawemaansimishan", ["gi", "dawemaaw2", "ns", "im", "ish", "an"]),
    ("nidawemaansinaanig", ["ni", "dawemaaw2", "ns", "inaan", "ig"]),
    ("nidawemaans", ["ni", "dawemaaw2", "ns"]),
    ("nidawemaansimishinaanig", ["ni", "dawemaaw2", "ns", "im", "ish", "inaan", "ig"]),
    ("nidawemaansimag", ["ni", "dawemaaw2", "ns", "im", "ag"]),
    ("gidawemaamishinaanin", ["gi", "dawemaaw2", "m", "ish", "inaan", "in"]),
    ("odawemaawaabaniin", ["o", "dawemaaw2", "waa", "aban", "iin"]),
    ("gidawemaansiminaaban", ["gi", "dawemaaw2", "ns", "im", "inaan", "aban"]),
    ("nidawemaan", ["ni", "dawemaaw2", "n"])
]

# %% [markdown]
# # Ten annotation for lemma 'daangosheny':

# %%
daangosheny_df = df_nouns[df_nouns['Lemma'] == 'daangosheny']
daangosheny_df.sample(10)
# Out:
#      Paradigm     Class        Lemma          Stem    PersPoss   Dim  Poss  \
# 1630      NAD  NAD_VVny  daangosheny  daangosheny1    InclPoss  NONE  NONE
# 1988      NAD  NAD_VVny  daangosheny  daangosheny1    InclPoss   Dim  NONE
# 1937      NAD  NAD_VVny  daangosheny  daangosheny1    ExclPoss  NONE  NONE
# 1784      NAD  NAD_VVny  daangosheny  daangosheny1     2SgPoss   Dim  Poss
# 1924      NAD  NAD_VVny  daangosheny  daangosheny1     2SgPoss  NONE  Poss
# 1891      NAD  NAD_VVny  daangosheny  daangosheny1    InclPoss   Dim  Poss
# 1762      NAD  NAD_VVny  daangosheny  daangosheny1  3PlObvPoss  NONE  NONE
# 1655      NAD  NAD_VVny  daangosheny  daangosheny1     1SgPoss   Dim  Poss
# 1792      NAD  NAD_VVny  daangosheny  daangosheny1    InclPoss   Dim  NONE
# 1676      NAD  NAD_VVny  daangosheny  daangosheny1     2SgPoss  NONE  Poss
#
#        Pej  Pret   Basic                  Form1Surface  \
# 1630  NONE  NONE     Loc           gidaangoshenyinaang
# ...

# %%
daangosheny_lst = [
    ("odaangoshenyimishini", ["o", "daangosheny1", "im", "ish", "ini"]),
    ("odaangoshenyimishini", ["o", "daangosheny1", "im", "ish", "ini"]),
    ("odaangoshenyensimisha'", ["o", "daangosheny1", "ens", "im", "ish", "a"]),
    ("nindaangoshenyensibaniig", ["ni", "daangosheny1", "ens", "ibaniig"]),
    ("gidaangoshenyishiwaag", ["gi", "daangosheny1", "ish", "iwaa", "g"]),
    ("nindaangoshenyensiman", ["ni", "daangosheny1", "ens", "im", "an"]),
    ("odaangoshenyiman", ["o", "daangosheny1", "im", "an"]),
    ("odaangoshenyimibanii'", ["o", "daangosheny1", "im", "ban", "ii"]),
    ("odaangoshenyensan", ["o", "daangosheny1", "ens", "an"]),
    ("odaangoshenyensing", ["o", "daangosheny1", "ens", "ing"])
]

# %%
lst = naan_lst + niigiigw_lst + shkanzhy_lst + dawemaaw_lst + daangosheny_lst

# %%
lst
# Out:
# [('ninaaning', ['ni', 'naan', 'ing']),
#  ('ninaaninaang', ['ni', 'naan', 'inaan', 'g']),
#  ('ginaaninaang', ['gi', 'naan', 'inaan', 'g']),
#  ('ginaaning', ['gi', 'naan', 'ing']),
#  ('ginaaniwaang', ['gi', 'naan', 'iwaa', 'ng']),
#  ('onaaning', ['o', 'naan', 'ing']),
#  ('onaaniwaang', ['o', 'naan', 'iwaa', 'ng']),
#  ('onaanining', ['o', 'naan', 'ining']),
#  ('onaanining', ['o', 'naan', 'ining']),
#  ('ninaanensing', ['ni', 'naan', 'ens', 'ing']),
#  ('ninaanensinaang', ['ni', 'naan', 'ens', 'inaan', 'g']),
#  ("oniigi'igoonsimining", ['o', "niigi'igw2", 'oons', 'im', 'in', 'ing']),
#  ("niniigi'igoonsimishag", ['ni', "niigi'igw2", 'oons', 'im', 'ish', 'ag']),
#  ("niniigi'igom", ['ni', "niigi'igw2", 'om']),
#  ("giniigi'igoonzhishiwaa'", ['gi', "niigi'igw2", 'oonzh', 'ish', 'iwaa']),
#  ("giniigi'igoonzhishing", ['gi', "niigi'igw2", 'oonzh', 'ish', 'ing']),
#  ("oniigi'igoonsini", ['o', "niigi'igw2", 'oons', 'ini']),
# ...
